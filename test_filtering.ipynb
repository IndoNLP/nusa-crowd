# %%
from dataclasses import dataclass
import pandas as pd
from nusantara import NusantaraMetadata, NusantaraConfigHelper
from nusantara.utils.constants import Tasks, TASK_TO_SCHEMA

# %%
conhelps = NusantaraConfigHelper()
print('All Configs')
print(conhelps)

# filter and load datasets
# ====================================================================
print('Retrieve SMSA')
print([helper for helper in conhelps.filtered(lambda x: ("smsa" in x.dataset_name and x.is_nusantara_schema))])
smsa_datasets = [
    helper.load_dataset()
    for helper in conhelps.filtered(
        lambda x: ("smsa" in x.dataset_name and x.is_nusantara_schema)
    )
]
print(smsa_datasets)

# examples of other filters
# ====================================================================

# get all source schema config helpers
print('Source datasets')
source_helpers = conhelps.filtered(lambda x: x.config.schema == "source")
print(source_helpers)

# get all nusantara config helpers
print('Nusantara datasets')
nusantara_helpers = conhelps.filtered(lambda x: x.is_nusantara_schema)
print(nusantara_helpers)

# nusantara NER public tasks
print('Nusantara NER public datasets')
nc_ner_public_helpers = conhelps.filtered(
    lambda x: (
        x.is_nusantara_schema
        and Tasks.NAMED_ENTITY_RECOGNITION in x.tasks
        and not x.is_local
    )
)
print(nc_ner_public_helpers)

# indolem datasets
print('IndoLEM datasets')
nc_indolem_helpers = conhelps.filtered(
    lambda x: ("indolem" in x.dataset_name and x.is_nusantara_schema)
)
print(nc_indolem_helpers)

# %%
meta_df = pd.read_csv('https://docs.google.com/spreadsheets/d/17o83IvWxmtGLYridZis0nEprHhsZIMeFtHGtXV35h6M/export?format=csv&gid=879729812', skiprows=1)
meta_df = meta_df[meta_df['Implemented'] > 0].rename({
    'No.': 'id', 'Name': 'name', 'Subsets': 'subsets', 'Link': 'source_link', 'Description': 'description',
    'HF Link': 'hf_link', 'License': 'license', 'Year': 'year', 'Collection Style': 'collection_style',
    'Language': 'language', 'Dialect': 'dialect', 'Domain': 'domain', 'Form': 'modality', 'Tasks': 'tasks',
    'Volume': 'volume', 'Unit': 'unit', 'Ethical Risks': 'ethical_risk', 'Provider': 'provider',
    'Paper Title': 'paper_title', 'Paper Link': 'paper_link', 'Access': 'access', 'Derived From': 'derived_from', 
    'Test Split': 'is_splitted', 'Notes': 'notes', 'Dataloader': 'dataloader', 'Implemented': 'implemented'
}, axis=1)
meta_df['is_splitted'] = meta_df['is_splitted'].apply(lambda x: True if x =='Yes' else False)
# [
#  'No.', 'Name', 'Subsets', 'Link', 'HF Link', 'License', 'Year',
#  'Language', 'Dialect', 'Domain', 'Form', 'Collection Style',
#  'Description', 'Volume', 'Unit', 'Ethical Risks', 'Provider',
#  'Paper Title', 'Paper Link', 'Access', 'Derived From', 'Tasks',
#  'Test Split', 'Notes', 'Dataloader', 'Implemented'
# ]

# %%
@dataclass
class MetaDict:
    data: dict = None

# %%
name_to_meta_map = {}
for cfg_meta in conhelps:
    # Assign metadata to meta dataframe
    meta_df.loc[meta_df.dataloader == cfg_meta.dataset_name, [
        'is_large', 'is_resource', 'is_default', 'is_broken',
        'is_local', 'citation', 'license', 'homepage', 'tasks'
    ]] = [
        cfg_meta.is_large, cfg_meta.is_resource, cfg_meta.is_default, cfg_meta.is_broken, 
        cfg_meta.is_local, cfg_meta.citation, cfg_meta.license, cfg_meta.homepage, '|'.join([task.value for task in cfg_meta.tasks])
    ]
    
    if cfg_meta.dataset_name not in name_to_meta_map:
        name_to_meta_map[cfg_meta.dataset_name] = {}
    if cfg_meta.config.schema not in name_to_meta_map[cfg_meta.dataset_name]:
        name_to_meta_map[cfg_meta.dataset_name][cfg_meta.config.schema] = []
    name_to_meta_map[cfg_meta.dataset_name][cfg_meta.config.schema].append(cfg_meta)

for dset_name in name_to_meta_map.keys():
    meta_df.loc[meta_df.dataloader == dset_name, 'metadata'] = MetaDict(data=name_to_meta_map[dset_name])

# %%
# Filter & load all Indonesian sentiment analysis task
lang = 'ind'
task = Tasks.SENTIMENT_ANALYSIS

filtered_df = meta_df.loc[
    (meta_df.tasks.str.contains(task.value)) & 
    (meta_df.language.str.contains(lang)) & meta_df.is_splitted
]

schema = f'nusantara_{TASK_TO_SCHEMA[task].lower()}'
datasets = {}
for metas in filtered_df.metadata:
    if schema in metas.data:
        for meta in metas.data[schema]:
            if len(meta.languages) > 1:
                if lang in meta.config.name:
                    datasets[meta.config.name] = meta.load_dataset()
            else:
                datasets[meta.config.name] = meta.load_dataset()

datasets
# Out:
#      id                                  name  \
# 2     3                                 CC100
# 10    8    Customer Review (Natasha Skincare)
# 12   10                  EmoT (IndoNLU Split)
# 13   11                               EmotCMT
# 15   13                                 FacQA
# 16   14                 HoASA (IndoNLU Split)
# 18   16                            ID Abusive
# 20   18                      ID Multilabel HS
# 23   21                       ID-HSD-Riomulia
# 26   24                Idn-tagged-corpus-CSUI
# 27   25                         IMDb Javanese
# 33   31                             IndoCoref
# 34   32                           IndoLEM NTP
# 35   33            IndoLEM Sentiment Analysis
# 36   34                IndoLEM Tweet Ordering
# 37   35                  Indonesian Clickbait
# 38   36    Indonesian general domain MT En-Id
# 39   37  Indonesian religious domain MT En-Id
# 42   40                   IndoNLG Bible En-Id
# 43   41                   IndoNLG Bible Jv-Id
# 44   42                   IndoNLG Bible Su-Id
# 45   43                               IndoNLI
# 47   45                               IndoSum
# 49   47                         InSet Lexicon
# 53   51                            Kamus Alay
# 54   52                                  KEPS
# 58   56                          MinangNLP MT
# 60   58               NER UGM (IndoLEM split)
# 61   59                NER UI (IndoLEM split)
# 63   61                  NERP (IndoNLU Split)
# 64   62                              Netifier
# 65   63                         News En-Id MT
# 66   64                              NusaX MT
# 79   65                       NusaX Sentiment
# 92   66                             PANL BPPT
# 93   67                             ParaCotta
# 95   69                  POSP (IndoNLU Split)
# 97   71                      Semeval STS Indo
# 98   72                            Singgalang
# 99   73                                  SmSA
# 101  75                        STIF-Indonesia
# 104  78  Sundanese-Indonesian Parallel Corpus
# 105  79                          TED En-Id MT
# 106  80                                 TermA
# 107  81                             TITML-IDN
# 108  82                             TyDiQA Id
# 114  88                               WikiAnn
# 119  93                                XL-Sum
#
#                                                subsets  \
# 2                                                  NaN
# 10                                                 NaN
# 12                                                 NaN
# 13                                 Indonesian, English
# 15                                                 NaN
# 16                                                 NaN
# 18                                                 NaN
# 20                                                 NaN
# 23                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 38                                                 NaN
# 39                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 47                                                 NaN
# 49                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 58                                                 NaN
# 60                                                 NaN
# 61                                                 NaN
# 63                                                 NaN
# 64                                          Indonesian
# 65                                                 NaN
# 66                                                 NaN
# 79                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 95                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 101                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 114  ind, jav, bug, min, bjn, sun, ace, tet, ms, ma...
# 119                                         Indonesian
#
#                                            source_link  \
# 2                      https://data.statmt.org/cc-100/
# 10   https://drive.google.com/file/d/1D1pHX7CxrI-eI...
# 12   https://github.com/IndoNLP/indonlu/tree/master...
# 13     https://github.com/ir-nlp-csui/CodeMixedEmotion
# 15   https://github.com/IndoNLP/indonlu/tree/master...
# 16   https://github.com/IndoNLP/indonlu/tree/master...
# 18   https://github.com/okkyibrohim/id-abusive-lang...
# 20   https://github.com/okkyibrohim/id-multi-label-...
# 23      https://github.com/ir-nlp-csui/id-hsd-riomulia
# 26   https://github.com/ir-nlp-csui/idn-tagged-corp...
# 27   https://huggingface.co/datasets/w11wo/imdb-jav...
# 33   https://github.com/valentinakania/indocoref/tr...
# 34                  https://github.com/indolem/indolem
# 35                  https://github.com/indolem/indolem
# 36                  https://github.com/indolem/indolem
# 37     https://data.mendeley.com/datasets/k42j7x2kpn/1
# 38   https://github.com/gunnxx/indonesian-mt-data/t...
# 39   https://github.com/gunnxx/indonesian-mt-data/t...
# 42   https://storage.googleapis.com/babert-pretrain...
# 43   https://storage.googleapis.com/babert-pretrain...
# 44   https://storage.googleapis.com/babert-pretrain...
# 45              https://github.com/ir-nlp-csui/indonli
# 47   https://drive.google.com/uc?export=download&id...
# 49                    https://github.com/fajri91/InSet
# 53           https://github.com/nasalsabila/kamus-alay
# 54   https://github.com/IndoNLP/indonlu/tree/master...
# 58                https://github.com/fajri91/minangNLP
# 60                  https://github.com/indolem/indolem
# 61                  https://github.com/indolem/indolem
# 63   https://github.com/IndoNLP/indonlu/tree/master...
# 64   https://github.com/ahmadizzan/netifier/tree/ma...
# 65   https://github.com/gunnxx/indonesian-mt-data/t...
# 66                    https://github.com/IndoNLP/nusax
# 79                    https://github.com/IndoNLP/nusax
# 92        https://huggingface.co/datasets/id_panl_bppt
# 93   https://drive.google.com/drive/u/1/folders/1AC...
# 95   https://github.com/IndoNLP/indonlu/tree/master...
# 97   https://github.com/ahmadizzan/sts-indo/tree/ma...
# 98           https://github.com/ir-nlp-csui/singgalang
# 99   https://github.com/IndoNLP/indonlu/tree/master...
# 101           https://github.com/haryoa/stif-indonesia
# 104  https://dataverse.telkomuniversity.ac.id/datas...
# 105  https://storage.googleapis.com/babert-pretrain...
# 106  https://github.com/IndoNLP/indonlu/tree/master...
# 107  https://huggingface.co/datasets/holylovenia/TI...
# 108  https://storage.googleapis.com/babert-pretrain...
# 114  https://drive.google.com/drive/folders/1Q-xdT9...
# 119               https://github.com/csebuetnlp/xl-sum
#
#                                                hf_link  \
# 2                https://huggingface.co/datasets/cc100
# 10                                                 NaN
# 12             https://huggingface.co/datasets/indonlu
# 13                                                 NaN
# 15             https://huggingface.co/datasets/indonlu
# 16             https://huggingface.co/datasets/indonlu
# 18                                                   -
# 20                                                   -
# 23                                                   -
# 26             https://huggingface.co/datasets/indonlu
# 27   https://huggingface.co/datasets/w11wo/imdb-jav...
# 33                                                   -
# 34                                                   -
# 35                                                   -
# 36                                                   -
# 37        https://huggingface.co/datasets/id_clickbait
# 38                                                   -
# 39                                                   -
# 42         https://huggingface.co/datasets/GEM/indonlg
# 43         https://huggingface.co/datasets/GEM/indonlg
# 44         https://huggingface.co/datasets/GEM/indonlg
# 45             https://huggingface.co/datasets/indonli
# 47         https://huggingface.co/datasets/GEM/indonlg
# 49                                                   -
# 53                                                 NaN
# 54             https://huggingface.co/datasets/indonlu
# 58                                                   -
# 60                                                   -
# 61                                                   -
# 63             https://huggingface.co/datasets/indonlu
# 64                                                 NaN
# 65                                                   -
# 66                                                   -
# 79                                                   -
# 92                                                   -
# 93                                                 NaN
# 95             https://huggingface.co/datasets/indonlu
# 97                                                 NaN
# 98                                                   -
# 99             https://huggingface.co/datasets/indonlu
# 101                                                  -
# 104                                   https://none.com
# 105        https://huggingface.co/datasets/GEM/indonlg
# 106            https://huggingface.co/datasets/indonlu
# 107  https://huggingface.co/datasets/holylovenia/TI...
# 108        https://huggingface.co/datasets/GEM/indonlg
# 114            https://huggingface.co/datasets/wikiann
# 119   https://huggingface.co/datasets/csebuetnlp/xlsum
#
#                                                license    year  \
# 2                               Common Crawl's license  2020.0
# 10                                             Unknown  2017.0
# 12                                        CC-BY-SA 4.0  2018.0
# 13                                             Unknown  2021.0
# 15                                        CC-BY-SA 4.0  2007.0
# 16                                        CC-BY-SA 4.0  2019.0
# 18                                     CC-BY-NC-SA 4.0  2018.0
# 20                                     CC-BY-NC-SA 4.0  2019.0
# 23                   unknown (looks like CC-BY-SA 4.0)  2017.0
# 26                                        CC-BY-SA 4.0  2014.0
# 27                                             Unknown  2021.0
# 33                                                 MIT  2021.0
# 34                                        CC BY-SA 3.0  2022.0
# 35                                        CC BY-SA 3.0  2022.0
# 36                                        CC BY-SA 3.0  2022.0
# 37                                           CC-BY 4.0  2020.0
# 38                                        CC-BY-SA 4.0  2020.0
# 39                                        CC-BY-SA 4.0  2020.0
# 42                                        CC-BY-SA 4.0  2021.0
# 43                                        CC-BY-SA 4.0  2021.0
# 44                                        CC-BY-SA 4.0  2021.0
# 45                                        CC-BY-SA 4.0  2021.0
# 47                                        CC-BY-SA 4.0  2021.0
# 49                                             unknown  2017.0
# 53                                             Unknown  2018.0
# 54                                        CC-BY-SA 4.0  2019.0
# 58                                                 MIT  2020.0
# 60                                        CC BY-SA 3.0  2014.0
# 61                                        CC BY-SA 3.0  2017.0
# 63                                        CC-BY-SA 4.0  2018.0
# 64                                     CC-BY-NC-SA 4.0  2018.0
# 65                                        CC-BY-SA 4.0  2021.0
# 66                                        CC-BY-SA 4.0  2022.0
# 79                                        CC-BY-SA 4.0  2022.0
# 92                                             unknown  2009.0
# 93                                             Unknown  2021.0
# 95                                        CC-BY-SA 4.0  2018.0
# 97                                             Unknown  2019.0
# 98                                             unknown  2017.0
# 99                                        CC-BY-SA 4.0  2020.0
# 101                                                MIT  2020.0
# 104                                                CC0  2015.0
# 105                                       CC-BY-SA 4.0  2021.0
# 106                                       CC-BY-SA 4.0  2019.0
# 107  For research purposes only. If you use this co...  2006.0
# 108                                       CC-BY-SA 4.0  2021.0
# 114                       Attribution License (ODC-By)  2017.0
# 119                                    CC-BY-NC-SA 4.0  2021.0
#
#                                               language     dialect  \
# 2                                        ind, sun, jav       other
# 10                                                 ind         NaN
# 12                                                 ind       other
# 13                                            ind, eng         NaN
# 15                                                 ind       other
# 16                                                 ind       other
# 18                                                 ind  colloquial
# 20                                                 ind  colloquial
# 23                                                 ind  colloquial
# 26                                                 ind      formal
# 27                                                 jav         NaN
# 33                                                 ind       other
# 34                                                 ind       other
# 35                                                 ind       other
# 36                                                 ind       other
# 37                                                 ind      formal
# 38                                            eng, ind       other
# 39                                            eng, ind       other
# 42                                            eng, ind      formal
# 43                                            jav, ind      formal
# 44                                            sun, ind      formal
# 45                                                 ind      formal
# 47                                                 ind      formal
# 49                                                 ind  colloquial
# 53                                          Indonesian         NaN
# 54                                                 ind       other
# 58                                            ind, min       other
# 60                                                 ind       other
# 61                                                 ind       other
# 63                                                 ind       other
# 64                                                 ind         NaN
# 65                                            eng, ind      formal
# 66   ind, ace, jav, sun, min, bug, bbc, ban, nij, m...       other
# 79   ind, ace, jav, sun, min, bug, bbc, ban, nij, m...       other
# 92                                            eng, ind       other
# 93                                            ind, eng         NaN
# 95                                                 ind       other
# 97                                            ind, eng         NaN
# 98                                                 ind      formal
# 99                                                 ind       other
# 101                                                ind       other
# 104                              Indonesian, Sundanese         NaN
# 105                                           eng, ind      formal
# 106                                                ind       other
# 107                                                ind         NaN
# 108                                                ind      formal
# 114  ind, eng, sun, jav, min, bug, bjn, tpi, ace, t...  Banyumasan
# 119                                         Indonesian         NaN
#
#                        domain  ...  \
# 2                multi domain  ...
# 10               Social media  ...
# 12               social media  ...
# 13               Social media  ...
# 15              news articles  ...
# 16              hotel reviews  ...
# 18               social media  ...
# 20               social media  ...
# 23               social media  ...
# 26              news articles  ...
# 27                    Reviews  ...
# 33                    general  ...
# 34               social media  ...
# 35               social media  ...
# 36               social media  ...
# 37              news articles  ...
# 38                    general  ...
# 39                   religion  ...
# 42                   religion  ...
# 43                   religion  ...
# 44                   religion  ...
# 45   news articles, Wikipedia  ...
# 47              news articles  ...
# 49               social media  ...
# 53               Social media  ...
# 54                    banking  ...
# 58                  wikipedia  ...
# 60              news articles  ...
# 61                    general  ...
# 63              news articles  ...
# 64               Social media  ...
# 65              news articles  ...
# 66                    reviews  ...
# 79                    reviews  ...
# 92              news articles  ...
# 93              News articles  ...
# 95              news articles  ...
# 97                    General  ...
# 98                  wikipedia  ...
# 99                    reviews  ...
# 101              social media  ...
# 104                 Wikipedia  ...
# 105                     mixed  ...
# 106             hotel reviews  ...
# 107             News articles  ...
# 108                     mixed  ...
# 114             Wiki articles  ...
# 119             News articles  ...
#
#                                               provider  \
# 2                                Multiple Institutions
# 10                              Tweet @NatashaSkinCare
# 12                               Universitas Indonesia
# 13                               Universitas Indonesia
# 15                  Toyohashi University of Technology
# 16                          Institut Teknologi Bandung
# 18                             IR-NLP Lab, Fasilkom UI
# 20                             IR-NLP Lab, Fasilkom UI
# 23                             IR-NLP Lab, Fasilkom UI
# 26                             IR-NLP Lab, Fasilkom UI
# 27   Wilson Wongso & Maas, Andrew L. and Daly, Raym...
# 33                             IR-NLP Lab, Fasilkom UI
# 34                               Multiple Institutions
# 35                               Multiple Institutions
# 36                               Multiple Institutions
# 37                              Univesitas Gadjah Mada
# 38                               Multiple Institutions
# 39                               Multiple Institutions
# 42                               Multiple Institutions
# 43                               Multiple Institutions
# 44                               Multiple Institutions
# 45                               Multiple Institutions
# 47                               Multiple Institutions
# 49                                          Fajri Koto
# 53                      Universitas Al Azhar Indonesia
# 54                                            Prosa.ai
# 58                               Multiple Institutions
# 60                              Universitas Gajah Mada
# 61                               Universitas Indonesia
# 63                                            Prosa.ai
# 64   Ahmad Izzan, Christian Wibisono, Ilham Firdaus...
# 65                               Multiple Institutions
# 66                              Multiple institutions
# 79                              Multiple institutions
# 92                                                BPPT
# 93                                             Kata.ai
# 95                                            Prosa.ai
# 97                                         Ahmad Izzan
# 98                             IR-NLP Lab, Fasilkom UI
# 99                          Institut Teknologi Bandung
# 101                              Multiple Institutions
# 104                                  Telkom University
# 105                              Multiple Institutions
# 106                              Multiple Institutions
# 107                      Tokyo Institute of Technology
# 108                              Multiple Institutions
# 114  Computer Science Department, Rensselaer Polyte...
# 119  Bangladesh University of Engineering and Techn...
#
#                                            paper_title  \
# 2    Unsupervised Cross-lingual Representation Lear...
# 10   CLASSIFICATION OF CUSTOMERS EMOTION USING NAÏV...
# 12   Emotion classification on indonesian\ntwitter ...
# 13   Normalisation of Indonesian-English Code-Mixed...
# 15   A Machine Learning Approach for\nIndonesian Qu...
# 16   Multi-label Aspect Categorization with Convolu...
# 18   A Dataset and Preliminaries Study for Abusive ...
# 20   Multi-label Hate Speech and Abusive Language D...
# 23   Hate Speech Detection in the Indonesian Langua...
# 26   Designing an Indonesian Part of speech Tagset ...
# 27   Causal and Masked Language Modeling of Javanes...
# 33   A Multi-Pass Sieve Coreference Resolution for ...
# 34   IndoLEM and IndoBERT: A Benchmark Dataset and ...
# 35   IndoLEM and IndoBERT: A Benchmark Dataset and ...
# 36   IndoLEM and IndoBERT: A Benchmark Dataset and ...
# 37   CLICK-ID: A novel dataset for Indonesian click...
# 38   Benchmarking Multidomain English-Indonesian Ma...
# 39   Benchmarking Multidomain English-Indonesian Ma...
# 42   IndoNLG: Benchmark and Resources for Evaluatin...
# 43   IndoNLG: Benchmark and Resources for Evaluatin...
# 44   IndoNLG: Benchmark and Resources for Evaluatin...
# 45   IndoNLI: A Natural Language Inference Dataset ...
# 47   Indosum: A new benchmark dataset for indonesia...
# 49   InSet Lexicon: Evaluation of a Word List for I...
# 53                       Colloquial Indonesian Lexicon
# 54   Improving Joint Layer RNN based Keyphrase Extr...
# 58   Towards Computational Linguistics in Minangkab...
# 60   Name Entity Recognition for Indonesian Text Us...
# 61   Automatic open domain information extraction f...
# 63   Investigating Bi-LSTM and CRF with POS Tag Emb...
# 64                                                 NaN
# 65   Benchmarking Multidomain English-Indonesian Ma...
# 66   NusaX: Multilingual Parallel Sentiment Dataset...
# 79   NusaX: Multilingual Parallel Sentiment Dataset...
# 92   Resource Report: Building Parallel Text Corpor...
# 93   ParaCotta: Synthetic Multilingual Paraphrase C...
# 95   Investigating Bi-LSTM and CRF with POS Tag Emb...
# 97                                                 NaN
# 98   Modified DBpedia Entities Expansion for Taggin...
# 99   Improving Bi-LSTM Performance for Indonesian S...
# 101  Semi-Supervised Low-Resource Style Transfer of...
# 104  Experiment on a phrase-based statistical machi...
# 105  When and Why Are Pre-Trained Word Embeddings U...
# 106  Aspect and Opinion Terms Extraction Using Doub...
# 107  A large vocabulary continuous speech recogniti...
# 108  IndoNLG: Benchmark and Resources for Evaluatin...
# 114  Cross-lingual Name Tagging and Linking for 282...
# 119  XL-Sum: Large-Scale Multilingual Abstractive S...
#
#                                             paper_link access  \
# 2          https://aclanthology.org/2020.acl-main.747/   Free
# 10   https://jurnal.uns.ac.id/itsmart/article/viewF...   Free
# 12        https://ieeexplore.ieee.org/document/8629262   Free
# 13   https://thesai.org/Downloads/Volume12No11/Pape...   Free
# 15   https://www.researchgate.net/publication/22117...   Free
# 16   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...   Free
# 18   https://www.sciencedirect.com/science/article/...   Free
# 20                  https://aclanthology.org/W19-3506/   Free
# 23   https://ieeexplore.ieee.org/abstract/document/...   Free
# 26   https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...   Free
# 27       https://ieeexplore.ieee.org/document/9631331/   Free
# 33            https://aclanthology.org/2021.ranlp-1.10   Free
# 34    https://aclanthology.org/2020.coling-main.66.pdf   Free
# 35    https://aclanthology.org/2020.coling-main.66.pdf   Free
# 36    https://aclanthology.org/2020.coling-main.66.pdf   Free
# 37   https://www.sciencedirect.com/science/article/...   Free
# 38             https://aclanthology.org/2020.bucc-1.6/   Free
# 39             https://aclanthology.org/2020.bucc-1.6/   Free
# 42       https://aclanthology.org/2021.emnlp-main.699/   Free
# 43       https://aclanthology.org/2021.emnlp-main.699/   Free
# 44       https://aclanthology.org/2021.emnlp-main.699/   Free
# 45       https://aclanthology.org/2021.emnlp-main.821/   Free
# 47                    https://arxiv.org/abs/1810.05334   Free
# 49   https://www.researchgate.net/publication/32175...   Free
# 53   https://ieeexplore.ieee.org/abstract/document/...   Free
# 54   https://www.semanticscholar.org/paper/Improvin...   Free
# 58          https://aclanthology.org/2020.paclic-1.17/   Free
# 60   http://etd.repository.ugm.ac.id/penelitian/det...   Free
# 61        https://ieeexplore.ieee.org/document/8275098   Free
# 63   https://www.semanticscholar.org/paper/Investig...   Free
# 64                                                 NaN   Free
# 65             https://aclanthology.org/2020.bucc-1.6/   Free
# 66                    https://arxiv.org/abs/2205.15960   Free
# 79                    https://arxiv.org/abs/2205.15960   Free
# 92                  https://aclanthology.org/W09-3413/   Free
# 93          https://aclanthology.org/2021.paclic-1.56/   Free
# 95   https://www.semanticscholar.org/paper/Investig...   Free
# 97                                                 NaN   Free
# 98        https://ieeexplore.ieee.org/document/8355036   Free
# 99        https://ieeexplore.ieee.org/document/8904199   Free
# 101             https://arxiv.org/pdf/2011.03286v1.pdf   Free
# 104  https://ieeexplore.ieee.org/abstract/document/...   Free
# 105                 https://aclanthology.org/N18-2084/   Free
# 106       https://ieeexplore.ieee.org/document/8904124   Free
# 107  https://www.researchgate.net/publication/22882...   Free
# 108      https://aclanthology.org/2021.emnlp-main.699/   Free
# 114              https://aclanthology.org/P17-1178.pdf   Free
# 119    https://aclanthology.org/2021.findings-acl.413/   Free
#
#                                           derived_from  \
# 2                                         Common Crawl
# 10                                                 NaN
# 12                                             Twitter
# 13   Normalization of indonesian-english code-mixed...
# 15                                           Wikipedia
# 16                                     Online Platform
# 18                                             Twitter
# 20                                 ID Abusive, Twitter
# 23                                             Twitter
# 26                                                   -
# 27                                        IMDb Dataset
# 33                                           Wikipedia
# 34                                             Twitter
# 35                                             Twitter
# 36                                             Twitter
# 37                              Online news publishers
# 38                            Wiki[x], Tatoeba, TALPCo
# 39                       Tanzil, JW300, Bible, Dsm-odb
# 42                                               Bible
# 43                                               Bible
# 44                                               Bible
# 45                                                   -
# 47                                     News aggregator
# 49                                                   -
# 53                                                 NaN
# 54                                                   -
# 58                                                   -
# 60                                                   -
# 61                                                   -
# 63                                                   -
# 64                                                 NaN
# 65   Pan Asia Networking Localization (PANL), Bilin...
# 66                                                SmSA
# 79                                                SmSA
# 92                                                   -
# 93            ParaBank2, Wikipedia, NewsCrawl, Tatoeba
# 95                                                   -
# 97                                                 NaN
# 98                                  Wikipedia, DBpedia
# 99                             Multiple Online Sources
# 101                                            Twitter
# 104                                                NaN
# 105                                   TED talk scripts
# 106                                                  -
# 107                                                NaN
# 108                                          Wikipedia
# 114                                                NaN
# 119                                                NaN
#
#                                tasks is_splitted  \
# 2                  Language Modeling       False
# 10            Emotion Classification        True
# 12            Emotion Classification        True
# 13            Emotion Classification       False
# 15   Question Answering (Extractive)        True
# 16   Aspect Based Sentiment Analysis        True
# 18             Hate Speech Detection       False
# 20             Hate Speech Detection       False
# 23             Hate Speech Detection       False
# 26                       POS Tagging        True
# 27                Sentiment Analysis        True
# 33            Coreference Resolution        True
# 34             Next Tweet Prediction        True
# 35                Sentiment Analysis        True
# 36                    Tweet Ordering        True
# 37               Clickbait Detection       False
# 38               Machine Translation        True
# 39               Machine Translation        True
# 42               Machine Translation        True
# 43               Machine Translation        True
# 44               Machine Translation        True
# 45        Natural Language Inference        True
# 47                     Summarization        True
# 49                Sentiment Analysis        True
# 53         Morphological Inflections       False
# 54                Keyword Extraction        True
# 58               Machine Translation        True
# 60           Named Entiy Recognition        True
# 61           Named Entiy Recognition        True
# 63           Named Entiy Recognition        True
# 64                Sentiment Analysis        True
# 65               Machine Translation        True
# 66               Machine Translation        True
# 79                Sentiment Analysis        True
# 92               Machine Translation       False
# 93                      Paraphrasing       False
# 95                       POS Tagging        True
# 97       Semantic Textual Similarity        True
# 98           Named Entiy Recognition       False
# 99                Sentiment Analysis        True
# 101    Style Transfer & Paraphrasing        True
# 104              Machine Translation       False
# 105              Machine Translation        True
# 106               Keyword Extraction        True
# 107     Automatic Speech Recognition       False
# 108  Question Answering (Extractive)        True
# 114          Named Entiy Recognition       False
# 119        Abstractive Summarization        True
#
#                                                  notes  \
# 2                                     No dataset split
# 10   Dataset Split: 87120 train, 37143 validation, ...
# 12   Dataset Split: 3521 train, 440 validation, 442...
# 13                                    No dataset split
# 15        Dataset Split: 2495 train, 311 dev, 311 test
# 16               Dataset Split: 7,560 train, 1890 test
# 18                                    No dataset split
# 20                                    No dataset split
# 23                                    No dataset split
# 26   Dataset Split: 8000 train, 1000 validation, 10...
# 27   Dataset Split: 25000 train, 0 validation, 2500...
# 33                                    No dataset split
# 34   Dataset Split:  5681 train, 811 validation, 18...
# 35   Dataset Split:  3638 train, 399 validation, 10...
# 36   Dataset Split:  5327 train, 760 validation, 15...
# 37                                    No dataset split
# 38   Dataset Split:  1729472 train, 2000 validation...
# 39   Dataset Split:  579544 train, 5000 validation,...
# 42   Dataset Split:  23308 training, 3109 validatio...
# 43   Dataset Split:  5967 train, 797 validation, 11...
# 44   Dataset Split:  5968 train, 797 validation, 11...
# 45   Dataset Split:  10330 train, 2197 validation, ...
# 47   Dataset Split:  14083 train, 1880 validation, ...
# 49                           Dataset Split:  2630 test
# 53                                    No dataset split
# 54                 Dataset Split: 1000 train, 247 test
# 58   Dataset Split:  11,571 train, 1600 validation,...
# 60   Dataset Split:  1687 train, 187 validation, 46...
# 61   Dataset Split:  1530 train, 170 validation, 42...
# 63   Dataset Split: 6720 train, 840 validation, 840...
# 64   Dataset Split: 6995 train, 0 validation, 778 test
# 65   Dataset Split:  38469 train, 1953 validation, ...
# 66         Dataset Split: 500 train, 100 dev, 400 test
# 79         Dataset Split: 500 train, 100 dev, 400 test
# 92                                    No dataset split
# 93                                    No dataset split
# 95   Dataset Split: 6720 train, 840 validation, 840...
# 97   Dataset Split: 10293 train, 0 validation, 2608...
# 98                                    No dataset split
# 99   Dataset Split: 11000 train, 1260 validation, 5...
# 101  Dataset Split: 1922 train, 214 validation, 363...
# 104                                   No dataset split
# 105  Dataset Split:  87406 train, 2677 validation, ...
# 106  Dataset Split: 3000 train, 1000 validation, 10...
# 107                                   No dataset split
# 108  Dataset Split:  4847 train, 565 validation, 85...
# 114                                   No dataset split
# 119  Dataset Split: 38242 train, 4780 validation, 4...
#
#                    dataloader implemented
# 2                       cc100         1.0
# 10   sentiment_nathasa_review         1.0
# 12                       emot         9.0
# 13                    emotcmt         1.0
# 15                      facqa         9.0
# 16                      hoasa         9.0
# 18                 id_abusive         1.0
# 20           id_multilabel_hs         1.0
# 23              id_hatespeech         1.0
# 26     idn_tagged_corpus_csui        17.0
# 27                    imdb_jv         1.0
# 33                  indocoref         1.0
# 34                indolem_ntp         1.0
# 35          indolem_sentiment         1.0
# 36     indolem_tweet_ordering         1.0
# 37               id_clickbait         1.0
# 38      indo_general_mt_en_id         1.0
# 39    indo_religious_mt_en_id         1.0
# 42                bible_en_id         1.0
# 43                bible_jv_id         1.0
# 44                bible_su_id         1.0
# 45                    indonli         1.0
# 47                    indosum         1.0
# 49              inset_lexicon         1.0
# 53                 kamus_alay         1.0
# 54                       keps         9.0
# 58               minangnlp_mt         1.0
# 60                     nerugm         1.0
# 61              indolem_nerui         9.0
# 63                       nerp         9.0
# 64                   netifier         1.0
# 65                 news_en_id         9.0
# 66                   nusax_mt         1.0
# 79                nusax_senti         1.0
# 92               id_panl_bppt         1.0
# 93                  paracotta         1.0
# 95                       posp         9.0
# 97                     id_sts         1.0
# 98                 singgalang         1.0
# 99                       smsa         9.0
# 101            stif_indonesia         1.0
# 104            parallel_su_id         1.0
# 105                 ted_en_id         9.0
# 106                    term_a         9.0
# 107                 titml_idn         1.0
# 108                 tydiqa_id         1.0
# 114                   wikiann         1.0
# 119                    xl_sum         1.0
#
# [48 rows x 26 columns]

# %%
# Filter & load all splitted English sentiment analysis task
lang = 'eng'
task = Tasks.MACHINE_TRANSLATION

filtered_df = meta_df.loc[
    (meta_df.tasks.str.contains(task.value)) & 
    (meta_df.language.str.contains(lang)) & meta_df.is_splitted
]

schema = f'nusantara_{TASK_TO_SCHEMA[task].lower()}'
datasets = {}
for metas in filtered_df.metadata:
    if schema in metas.data:
        for meta in metas.data[schema]:
            if len(meta.languages) > 1:
                if lang in meta.config.name:
                    datasets[meta.config.name] = meta.load_dataset()
            else:
                datasets[meta.config.name] = meta.load_dataset()
                
datasets

# %%
 meta_df.loc[
    (meta_df.name.str.contains('CSUI'))
]

# %%
for cfg_meta in conhelps:
    if len(cfg_meta.tasks) > 1:
        print(cfg_meta.name)

# %%
# Filter & load all Indonesian sentiment analysis task
lang = 'ind'
task = Tasks.SENTIMENT_ANALYSIS

filtered_df = meta_df.loc[
    (meta_df.tasks.str.contains(task.value)) & 
    (meta_df.language.str.contains(lang)) & meta_df.is_splitted
]

schema = f'nusantara_{TASK_TO_SCHEMA[task].lower()}'
datasets = {}
for metas in filtered_df.metadata:
    if schema in metas.data:
        for meta in metas.data[schema]:
            if len(meta.languages) > 1:
                if lang in meta.config.name:
                    datasets[meta.config.name] = meta.load_dataset()
            else:
                datasets[meta.config.name] = meta.load_dataset()

datasets

# %%
If there is multiple tasks on a dataset, split it and filter schema out of it resulting in
config meta from the original dataset meta
